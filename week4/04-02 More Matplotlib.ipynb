# %%
# credit to Jake VanderPlas Python Data Science Handbook

# %%
# standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# colors
x = np.linspace(0, 10, 1000)
plt.plot(x, x, color = 'g')
plt.plot(x, x+1, color = 'r')
plt.plot(x, x+2, color = 'b')

plt.plot(x, x+4, color = 'cornflowerblue')
plt.plot(x, x+5, color = 'skyblue')
plt.show()

# %% [markdown]
# |character|color|
# |---|---|
# |'b'|blue|
# |'g'|green|
# |'r'|red|
# |'c'|cyan|
# |'m'|magenta|
# |'y'|yellow|
# |'k'|black|
# |'w'|white|
#
# List of Named Colors: <https://matplotlib.org/examples/color/named_colors.html>

# %%
# line style
x = np.linspace(0, 10, 1000)
plt.plot(x,  x , linestyle = '-')  # solid
plt.plot(x, x+1, linestyle = '--') # dashed
plt.plot(x, x+2, linestyle = '-.') # dash dot
plt.plot(x, x+3, linestyle = ':')  # dotted
plt.show()

# default behavior uses different colors for multiple lines

# %%
np.random.seed(1)
x = np.random.random(100)
y = np.random.random(100)
plt.figure(figsize = (4,4)) # length by height
plt.scatter(x,y)
plt.axis('equal')
plt.show()

# %%
z = 100 * np.random.randint(0,10,100)  # use for size
w = np.random.randint(0,5,100) # use for color
print(z)
print(w)
# Out:
# [100 300 100 200 200 300 900 200 600 200 900 100 100 500 400 800 400 700
#  200 300   0 500 800 200 900 400   0   0 300 400 900 600 700 600 800   0
#  800   0 500 200   0 800 600 100 900 500   0   0 800 100 300 700 500 100
#  200 600 300 200 100 800 600 500 900 100 500 100 600 300   0 500 700 300
#  200 900 400 400 400 900 900 900 400 800 100 600 600 700 200 400 500 700
#  300 700 100 600 700 900 400 800 700   0]
# [4 1 1 0 4 1 1 0 3 4 3 3 2 2 1 2 2 1 3 3 2 3 3 3 3 3 0 3 3 1 0 4 3 1 2 3 1
#  2 0 2 2 0 2 0 0 4 0 2 2 2 0 1 4 1 2 1 0 1 0 1 3 2 4 3 4 2 1 3 2 0 2 3 4 2
#  1 2 2 3 3 4 3 3 4 2 3 2 0 3 1 3 1 4 3 4 4 0 3 3 0 1]

# %%
colors = np.array(['r','b','g','m','y'])
c = colors[w]
print(c)
# Out:
# ['y' 'b' 'b' 'r' 'y' 'b' 'b' 'r' 'm' 'y' 'm' 'm' 'g' 'g' 'b' 'g' 'g' 'b'
#  'm' 'm' 'g' 'm' 'm' 'm' 'm' 'm' 'r' 'm' 'm' 'b' 'r' 'y' 'm' 'b' 'g' 'm'
#  'b' 'g' 'r' 'g' 'g' 'r' 'g' 'r' 'r' 'y' 'r' 'g' 'g' 'g' 'r' 'b' 'y' 'b'
#  'g' 'b' 'r' 'b' 'r' 'b' 'm' 'g' 'y' 'm' 'y' 'g' 'b' 'm' 'g' 'r' 'g' 'm'
#  'y' 'g' 'b' 'g' 'g' 'm' 'm' 'y' 'm' 'm' 'y' 'g' 'm' 'g' 'r' 'm' 'b' 'm'
#  'b' 'y' 'm' 'y' 'y' 'r' 'm' 'm' 'r' 'b']

# %%
plt.scatter(x, y, s = z, c = c, alpha = 0.3)  # alpha modifies transparency
plt.show()

# %%
plt.scatter(x, y, s = z, c = c, marker = "*", alpha = 0.3)  # can change the point markers
# But you can't map the markers to a variable
plt.show()

plt.scatter(x, y, s = z, c = c, marker = "d", alpha = 0.3) 
plt.show()

# %% [markdown]
# | character | description           |
# |:---------:|-----------------------|
# |    '.'    | point marker          |
# |    ','    | pixel marker          |
# |    'o'    | circle marker         |
# |    'v'    | triangle_down marker  |
# |    '^'    | triangle_up marker    |
# |    '<'    | triangle_left marker  |
# |    '>'    | triangle_right marker |
# |    '1'    | tri_down marker       |
# |    '2'    | tri_up marker         |
# |    '3'    | tri_left marker       |
# |    '4'    | tri_right marker      |
# |    's'    | square marker         |
# |    'p'    | pentagon marker       |
# |    '*'    | star marker           |
# |    'h'    | hexagon1 marker       |
# |    'H'    | hexagon2 marker       |
# |    '+'    | plus marker           |
# |    'x'    | x marker              |
# |    'D'    | diamond marker        |
# |    'd'    | thin_diamond marker   |

# %%
# Subplots
for i in range(1, 7):
    plt.subplot(2, 3, i)   # two rows of subplots, three columns of plots, work in plot i
    plt.text(0.5, 0.5, str((2, 3, i)), fontsize=18,ha='center')  
    # plt.text adds text, first two will be the xy position, the character string

# %%
# Subplots
for i in range(1, 7):
    plt.subplot(2, 3, i)   # two rows of subplots, three columns of plots, work in plot i
    plt.text(0.5, 0.5, "(2, 3, i)", fontsize=18,ha='center')  
    # plt.text adds text, first two will be the xy position, the character string

# %%
# More Complicated Grids
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)
plt.subplot(grid[0, 0]) # gridspec uses 0 based indexing
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);
plt.show()

# %%
# More Complicated Grids
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)   # number of rows by number of columns
plt.subplot(grid[0, 0]) # gridspec uses 0 based indexing
plt.subplot(grid[0, 1])
plt.subplot(grid[0, 2])

plt.subplot(grid[1, 0])
plt.subplot(grid[1, 1])
plt.subplot(grid[1, 2]);
plt.show()

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4)   ## 4 x 4 grid
main_ax = fig.add_subplot(grid[:-1, 1:]) # vertically, we start at the beginning, and leave one space
# horizontally, we start at the second and go to the end

y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax) # share y axis with main, no ticks on x
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax) # share x axis with main, no ticks on y

# scatter points on the main axes
main_ax.plot(x, y, 'o', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, bins=40, histtype='stepfilled',
            orientation='vertical', color='skyblue')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='skyblue')
y_hist.invert_xaxis()

# %%
# more histograms

data = np.random.randn(1000)

plt.hist(data)
plt.show()

# %%
plt.hist(data, bins=30, alpha=0.5,
         histtype='stepfilled', 
         color='steelblue',
         edgecolor='blue')
plt.show()

# %%
plt.hist(data, bins=30, alpha=0.5,
         color='steelblue',
         edgecolor='blue')
plt.show()

# %%
plt.hist(data, bins=30, alpha=0.5,
         histtype='step', 
         color='steelblue',
        edgecolor="blue")
plt.show()

# %%
plt.hist(data, bins=30, alpha=0.5,
         histtype='stepfilled', 
         color='steelblue',
        edgecolor="none",
        density=True)
plt.show()

# %%
x1 = np.random.normal(0, 0.8, 10000)
x2 = np.random.normal(-2, 1, 10000)
x3 = np.random.normal(3, 2, 10000)

# define a dictionary
# if we want to change the format of hist, we would not need to change hist plot one by one, instead of changing the dictionary
kwargs = dict(histtype='stepfilled', alpha=0.2, density=True, bins=40)

# plug dictionary into hist via **dictionary name
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);
plt.show()

# %%
# 2dimension hist plot
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T
plt.hist2d(x,y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')
