# %%
import pandas as pd
import numpy as np

# %%
bmx = pd.read_sas('BMX_I.XPT')

# %%
bmx.head()
# Out:
#       SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1  83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2  83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3  83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4  83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
#
#    BMXHT  BMIHT    ...     BMXARMC  BMIARMC  BMXWAIST  BMIWAIST  BMXSAD1  \
# 0  184.5    NaN    ...        35.9      NaN     101.1       NaN     22.9
# 1  171.4    NaN    ...        33.2      NaN     107.9       NaN     27.5
# 2  170.1    NaN    ...        31.0      NaN     116.5       NaN     26.7
# 3  160.9    NaN    ...        38.3      NaN     110.1       NaN     25.2
# 4  164.9    NaN    ...        27.2      NaN      80.4       NaN      NaN
#
#    BMXSAD2  BMXSAD3  BMXSAD4  BMDAVSAD  BMDSADCM
# ...

# %%
bmx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9544 entries, 0 to 9543
# Data columns (total 26 columns):
# SEQN        9544 non-null float64
# BMDSTATS    9544 non-null float64
# BMXWT       9445 non-null float64
# BMIWT       443 non-null float64
# BMXRECUM    1073 non-null float64
# BMIRECUM    33 non-null float64
# BMXHEAD     215 non-null float64
# BMIHEAD     0 non-null float64
# BMXHT       8769 non-null float64
# BMIHT       105 non-null float64
# BMXBMI      8756 non-null float64
# BMDBMIC     3340 non-null float64
# BMXLEG      7110 non-null float64
# BMILEG      402 non-null float64
# BMXARML     8976 non-null float64
# BMIARML     420 non-null float64
# BMXARMC     8976 non-null float64
# BMIARMC     421 non-null float64
# BMXWAIST    8313 non-null float64
# BMIWAIST    489 non-null float64
# BMXSAD1     6983 non-null float64
# BMXSAD2     6983 non-null float64
# BMXSAD3     353 non-null float64
# BMXSAD4     353 non-null float64
# BMDAVSAD    6983 non-null float64
# ...

# %%
demo = pd.read_sas('DEMO_I.XPT')

# %%
demo.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM    ...     DMDHREDU  DMDHRMAR  DMDHSEDU  \
# 0       3.0       1.0       NaN    ...          5.0       1.0       3.0
# 1       3.0       1.0       NaN    ...          3.0       3.0       NaN
# 2       3.0       2.0       NaN    ...          3.0       1.0       3.0
# 3       3.0       2.0       NaN    ...          5.0       6.0       NaN
# 4       4.0       2.0       NaN    ...          4.0       3.0       NaN
#
#         WTINT2YR       WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  \
# ...

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9971 entries, 0 to 9970
# Data columns (total 47 columns):
# SEQN        9971 non-null float64
# SDDSRVYR    9971 non-null float64
# RIDSTATR    9971 non-null float64
# RIAGENDR    9971 non-null float64
# RIDAGEYR    9971 non-null float64
# RIDAGEMN    695 non-null float64
# RIDRETH1    9971 non-null float64
# RIDRETH3    9971 non-null float64
# RIDEXMON    9544 non-null float64
# RIDEXAGM    4060 non-null float64
# DMQMILIZ    6149 non-null float64
# DMQADFC     527 non-null float64
# DMDBORN4    9971 non-null float64
# DMDCITZN    9969 non-null float64
# DMDYRSUS    2236 non-null float64
# DMDEDUC3    2647 non-null float64
# DMDEDUC2    5719 non-null float64
# DMDMARTL    5719 non-null float64
# RIDEXPRG    1288 non-null float64
# SIALANG     9971 non-null float64
# SIAPROXY    9970 non-null float64
# SIAINTRP    9971 non-null float64
# FIALANG     9642 non-null float64
# FIAPROXY    9642 non-null float64
# ...

# %%
# Detect missing values (NaN in numeric arrays, None/NaN in object arrays) for "RIDEXMON"
demo.loc[demo.RIDEXMON.isnull()]
# Out:
#          SEQN  SDDSRVYR  RIDSTATR  RIAGENDR      RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 26    83758.0       9.0       1.0       1.0  8.000000e+01       NaN       3.0
# 39    83771.0       9.0       1.0       2.0  2.000000e+00       NaN       1.0
# 50    83782.0       9.0       1.0       2.0  5.397605e-79       4.0       3.0
# 114   83846.0       9.0       1.0       2.0  4.100000e+01       NaN       4.0
# 118   83850.0       9.0       1.0       1.0  1.300000e+01       NaN       3.0
# 129   83861.0       9.0       1.0       1.0  8.000000e+01       NaN       3.0
# 145   83877.0       9.0       1.0       2.0  1.300000e+01       NaN       5.0
# 161   83893.0       9.0       1.0       2.0  6.800000e+01       NaN       1.0
# 172   83904.0       9.0       1.0       2.0  8.000000e+01       NaN       4.0
# 195   83927.0       9.0       1.0       2.0  6.600000e+01       NaN       5.0
# 213   83945.0       9.0       1.0       2.0  9.000000e+00       NaN       1.0
# ...

# %%
# remove the rows which "RIDEXMON" and "RIDEXAGM" is NaN
demo.loc[((~demo.RIDEXMON.isnull()) & (~demo.RIDEXAGM.isnull()))]
# Out:
#          SEQN  SDDSRVYR  RIDSTATR  RIAGENDR      RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 6     83738.0       9.0       2.0       2.0  1.100000e+01       NaN       1.0
# 7     83739.0       9.0       2.0       1.0  4.000000e+00       NaN       3.0
# 8     83740.0       9.0       2.0       1.0  1.000000e+00      13.0       2.0
# 11    83743.0       9.0       2.0       1.0  1.800000e+01       NaN       5.0
# 13    83745.0       9.0       2.0       2.0  1.500000e+01       NaN       3.0
# 14    83746.0       9.0       2.0       2.0  4.000000e+00       NaN       5.0
# 16    83748.0       9.0       2.0       1.0  3.000000e+00       NaN       4.0
# 17    83749.0       9.0       2.0       2.0  1.700000e+01       NaN       3.0
# 19    83751.0       9.0       2.0       2.0  1.600000e+01       NaN       1.0
# 21    83753.0       9.0       2.0       1.0  1.500000e+01       NaN       4.0
# 24    83756.0       9.0       2.0       1.0  1.600000e+01       NaN       3.0
# ...

# %%
merged = bmx.merge(right = demo, on = 'SEQN')
merged.head()
# Out:
#       SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  83732.0       1.0   94.8    NaN       NaN       NaN      NaN      NaN
# 1  83733.0       1.0   90.4    NaN       NaN       NaN      NaN      NaN
# 2  83734.0       1.0   83.4    NaN       NaN       NaN      NaN      NaN
# 3  83735.0       1.0  109.8    NaN       NaN       NaN      NaN      NaN
# 4  83736.0       3.0   55.2    NaN       NaN       NaN      NaN      NaN
#
#    BMXHT  BMIHT    ...     DMDHREDU  DMDHRMAR  DMDHSEDU       WTINT2YR  \
# 0  184.5    NaN    ...          5.0       1.0       3.0  134671.370419
# 1  171.4    NaN    ...          3.0       3.0       NaN   24328.560239
# 2  170.1    NaN    ...          3.0       1.0       3.0   12400.008522
# 3  160.9    NaN    ...          5.0       6.0       NaN  102717.995647
# 4  164.9    NaN    ...          4.0       3.0       NaN   17627.674984
#
#         WTMEC2YR  SDMVPSU  SDMVSTRA  INDHHIN2  INDFMIN2  INDFMPIR
# ...

# %%
merged2 = demo.merge(right = bmx, on = 'SEQN')
merged2.head()
# Out:
#       SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  83732.0       9.0       2.0       1.0      62.0       NaN       3.0
# 1  83733.0       9.0       2.0       1.0      53.0       NaN       3.0
# 2  83734.0       9.0       2.0       1.0      78.0       NaN       3.0
# 3  83735.0       9.0       2.0       2.0      56.0       NaN       3.0
# 4  83736.0       9.0       2.0       2.0      42.0       NaN       4.0
#
#    RIDRETH3  RIDEXMON  RIDEXAGM    ...     BMXARMC  BMIARMC  BMXWAIST  \
# 0       3.0       1.0       NaN    ...        35.9      NaN     101.1
# 1       3.0       1.0       NaN    ...        33.2      NaN     107.9
# 2       3.0       2.0       NaN    ...        31.0      NaN     116.5
# 3       3.0       2.0       NaN    ...        38.3      NaN     110.1
# 4       4.0       2.0       NaN    ...        27.2      NaN      80.4
#
#    BMIWAIST  BMXSAD1  BMXSAD2  BMXSAD3  BMXSAD4  BMDAVSAD  BMDSADCM
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9544 entries, 0 to 9543
# Data columns (total 72 columns):
# SEQN        9544 non-null float64
# BMDSTATS    9544 non-null float64
# BMXWT       9445 non-null float64
# BMIWT       443 non-null float64
# BMXRECUM    1073 non-null float64
# BMIRECUM    33 non-null float64
# BMXHEAD     215 non-null float64
# BMIHEAD     0 non-null float64
# BMXHT       8769 non-null float64
# BMIHT       105 non-null float64
# BMXBMI      8756 non-null float64
# BMDBMIC     3340 non-null float64
# BMXLEG      7110 non-null float64
# BMILEG      402 non-null float64
# BMXARML     8976 non-null float64
# BMIARML     420 non-null float64
# BMXARMC     8976 non-null float64
# BMIARMC     421 non-null float64
# BMXWAIST    8313 non-null float64
# BMIWAIST    489 non-null float64
# BMXSAD1     6983 non-null float64
# BMXSAD2     6983 non-null float64
# BMXSAD3     353 non-null float64
# BMXSAD4     353 non-null float64
# BMDAVSAD    6983 non-null float64
# ...

# %%
## rows that do not have missing values for the variable AGE in months. persons between 0 and 24 months
babies = merged.loc[merged['RIDAGEMN'].isnull() == False]

# %%
# or
## rows that do not have missing values for the variable AGE in months. persons between 0 and 24 months
babies = merged.loc[~merged.RIDAGEMN.isnull()]

# %%
print(babies.loc[:, ['RIDAGEMN', 'BMXWT']].info())
# only have 661 babies with body weight measurements
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 662 entries, 8 to 9533
# Data columns (total 2 columns):
# RIDAGEMN    662 non-null float64
# BMXWT       661 non-null float64
# dtypes: float64(2)
# memory usage: 15.5 KB
# None

# %%
# or 
print(babies.loc[:, ('RIDAGEMN', 'BMXWT')].info())
# only have 661 babies with body weight measurements
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 662 entries, 8 to 9533
# Data columns (total 2 columns):
# RIDAGEMN    662 non-null float64
# BMXWT       661 non-null float64
# dtypes: float64(2)
# memory usage: 15.5 KB
# None

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(babies.RIDAGEMN, babies.BMXWT)
plt.show()

# %%
babies.loc[ np.round(babies['RIDAGEMN'], 2) == 0, "RIDAGEMN"].head()
# Out:
# 214     5.397605e-79
# 295     5.397605e-79
# 1641    5.397605e-79
# 1744    5.397605e-79
# 1748    5.397605e-79
# Name: RIDAGEMN, dtype: float64

# %%
# simple example for np.round
print(np.round(1.23456789,2))
print(np.round(5.397605e-79,2)==0)
# Out:
# 1.23
# True

# %%
# average weight of a 0 month old
# we had to use np.round because testing for direct equality to 0 resulted in 0 values returned
babies.loc[ np.round(babies['RIDAGEMN'], 2) == 0 , 'BMXWT'].plot(kind = 'box')

# %%
print(babies['RIDAGEMN'].astype(int)==0)
# Out:
# 8       False
# 32      False
# 45      False
# 62      False
# 63      False
# 69      False
# 105     False
# 107     False
# 115     False
# 121     False
# 153     False
# 171     False
# 181     False
# 182     False
# 197     False
# 200     False
# 213     False
# 214      True
# 259     False
# 295      True
# 299     False
# 304     False
# 311     False
# 315     False
# 318     False
# 330     False
# 352     False
# 364     False
# 372     False
# 383     False
#         ...
# 8969    False
# 8992    False
# 9012    False
# 9025    False
# 9050    False
# 9056    False
# 9065    False
# 9079    False
# 9086    False
# 9156     True
# 9187    False
# 9229    False
# 9230    False
# 9249    False
# 9259    False
# 9265    False
# 9275    False
# 9293    False
# 9344    False
# 9354    False
# 9368    False
# 9388    False
# 9425    False
# 9429    False
# 9430    False
# 9472    False
# 9480    False
# 9520    False
# 9529    False
# 9533    False
# ...

# %%
# We could have also converted Age in months to integers
babies.loc[ babies['RIDAGEMN'].astype(int) == 0 , 'BMXWT'].plot(kind = 'box')
plt.ylabel("mean")
plt.show()
print(babies.loc[ babies['RIDAGEMN'].astype(int) == 0 , 'BMXWT'].mean()) # mean weight of babies that are 0 months old
# Out:
# 4.680000000000001

# %%
sns.lmplot(x = 'RIDAGEMN', y = 'BMXWT', hue = 'RIDRETH3', data = babies)

# %%
sns.lmplot(x = 'RIDAGEMN', y = 'BMXWT', hue = 'RIDRETH3', col = 'RIDRETH3', data = babies)  # col stand for columns

# %%
babies.groupby(['RIDAGEMN','RIDRETH3'])['BMXWT'].describe()
# Out:
#                        count       mean       std   min     25%    50%  \
# RIDAGEMN     RIDRETH3
# 5.397605e-79 1.0        11.0   4.809091  0.401135   4.3   4.450   4.90
#              2.0         3.0   4.733333  0.251661   4.5   4.600   4.70
#              3.0        13.0   4.592308  0.670151   3.7   4.100   4.40
#              4.0         2.0   4.350000  1.060660   3.6   3.975   4.35
#              7.0         1.0   4.900000       NaN   4.9   4.900   4.90
# 1.000000e+00 1.0         7.0   5.628571  0.882637   4.5   5.200   5.50
#              2.0         3.0   5.833333  0.503322   5.3   5.600   5.90
#              3.0        11.0   5.836364  1.093867   4.4   4.950   5.50
#              4.0         8.0   5.325000  0.613538   4.2   5.050   5.30
#              6.0         4.0   5.100000  0.765942   4.1   4.700   5.30
# 2.000000e+00 1.0        11.0   5.890909  1.125571   4.2   5.150   5.80
#              2.0         4.0   6.600000  0.163299   6.4   6.550   6.60
# ...
